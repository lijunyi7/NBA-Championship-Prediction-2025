# %%
from nba_api.stats.endpoints import leaguedashteamstats, leaguestandings
import pandas as pd
import time

# %%
year = 2025
time.sleep(1)
standings = leaguestandings.LeagueStandings(season=f"{year-1}-{str(year)[-2:]}")
standings_df = standings.get_data_frames()[0]

standings_df = standings_df[[
    'TeamID', 'TeamCity', 'TeamName', 'Conference', 'PlayoffRank', 'WINS', 'LOSSES', 'WinPCT'
]]
standings_df['TEAM'] = standings_df['TeamCity'] + ' ' + standings_df['TeamName']
# east = df[df['CONF_RANK'] <= 8]
# west = df[df['CONF_RANK'] > 8].sort_values(by='W_PCT', ascending=False).head(8)
# playoff_teams = pd.concat([east, west])
standings_df
# Out:
#         TeamID       TeamCity       TeamName Conference  PlayoffRank  WINS  \
# 0   1610612760  Oklahoma City        Thunder       West            1    68
# 1   1610612739      Cleveland      Cavaliers       East            1    64
# 2   1610612738         Boston        Celtics       East            2    61
# 3   1610612745        Houston        Rockets       West            2    52
# 4   1610612752       New York         Knicks       East            3    51
# 5   1610612747    Los Angeles         Lakers       West            3    50
# 6   1610612743         Denver        Nuggets       West            4    50
# 7   1610612754        Indiana         Pacers       East            4    50
# 8   1610612746             LA       Clippers       West            5    50
# 9   1610612749      Milwaukee          Bucks       East            5    48
# 10  1610612750      Minnesota   Timberwolves       West            6    49
# 11  1610612765        Detroit        Pistons       East            6    44
# 12  1610612744   Golden State       Warriors       West            7    48
# 13  1610612753        Orlando          Magic       East            7    41
# 14  1610612763        Memphis      Grizzlies       West            8    48
# 15  1610612737        Atlanta          Hawks       East            8    40
# 16  1610612758     Sacramento          Kings       West            9    40
# 17  1610612741        Chicago          Bulls       East            9    39
# 18  1610612742         Dallas      Mavericks       West           10    39
# 19  1610612748          Miami           Heat       East           10    37
# 20  1610612761        Toronto        Raptors       East           11    30
# 21  1610612756        Phoenix           Suns       West           11    36
# 22  1610612751       Brooklyn           Nets       East           12    26
# 23  1610612757       Portland  Trail Blazers       West           12    36
# 24  1610612755   Philadelphia          76ers       East           13    24
# 25  1610612759    San Antonio          Spurs       West           13    34
# 26  1610612740    New Orleans       Pelicans       West           14    21
# 27  1610612766      Charlotte        Hornets       East           14    19
# 28  1610612764     Washington        Wizards       East           15    18
# 29  1610612762           Utah           Jazz       West           15    17
#
#     LOSSES  WinPCT                    TEAM
# 0       14   0.829   Oklahoma City Thunder
# 1       18   0.780     Cleveland Cavaliers
# 2       21   0.744          Boston Celtics
# 3       30   0.634         Houston Rockets
# 4       31   0.622         New York Knicks
# 5       32   0.610      Los Angeles Lakers
# 6       32   0.610          Denver Nuggets
# 7       32   0.610          Indiana Pacers
# 8       32   0.610             LA Clippers
# 9       34   0.585         Milwaukee Bucks
# 10      33   0.598  Minnesota Timberwolves
# 11      38   0.537         Detroit Pistons
# 12      34   0.585   Golden State Warriors
# 13      41   0.500           Orlando Magic
# 14      34   0.585       Memphis Grizzlies
# 15      42   0.488           Atlanta Hawks
REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  \
# 0    0.472  ...        14         2        26         2        12         15
# 1    0.462  ...         8        16         2        29         5          1
# 2    0.437  ...        29        24        23        20        26         27
# 3    0.430  ...         9        26        25        26        21         23
# 4    0.470  ...         3         5        20        24        18         18
# 5    0.491  ...         6         9         3        14        27          8
# 6    0.479  ...        23        22        13        21         7         12
# 7    0.506  ...         4         1        17        17        15         19
# 8    0.476  ...        13        15        21        19         9         17
# 9    0.451  ...         7         4        14         4        17         24
# 10   0.455  ...         1        28        11        10        13         28
# 11   0.488  ...        28         3         3         9         6         10
# 12   0.482  ...        17        23        22         3        20          6
# 13   0.479  ...        26        18        12        22        22          4
# 14   0.479  ...         2         8        28         7         3         25
# 15   0.465  ...        21        14         8        15        30         13
# 16   0.486  ...        22        21         7        27        19          2
# 17   0.468  ...        15        17        18        18        14         11
# 18   0.452  ...        20        19        19         8        10         21
# 19   0.486  ...        24        11         5        13        29         16
# 20   0.482  ...        11        12         1         1         2         14
# 21   0.445  ...        27        30        16         6         1          8
# 22   0.454  ...        30        29         9         5        23         19
# 23   0.478  ...        25        10        15        28        16          3
# 24   0.450  ...        12        27        29        11         8         26
# 25   0.478  ...        16        13         6        25        25          5
# 26   0.465  ...        19         6        10        12         4          7
# 27   0.458  ...        10         7        24        16        28         29
# 28   0.454  ...         5        20        30        30        24         30
# 29   0.439  ...        18        25        27        23        11         21
#
#     PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK
# 0        22         8         5               18
# 1         2        27         8                3
# 2        28        14        29               26
# 3        16        22        30               27
# 4         6        30         6               20
# 5        11        11         1                2
# 6         8        16        15               19
# 7         6         9         3                9
# 8        27        13        12               13
# 9        23        18        17               10
# 10       20         5        13                7
# 11       15        15         7               12
# 12       14        26        20                6
# 13        5         6        19               14
# 14       29         2         2                5
# 15        1        29        24               15
# 16        9        12        11               11
# 17       12         7        13                4
# 18       13        25        25               29
# 19        4        10         9                8
# 20       25        23         4                1
# 21       26         1        28               17
# 22       19        17        26               25
# 23       10        20        18               23
# 24       21         3        22               22
# 25       17        19        10               16
# 26        3        28        16               21
# 27       30        24        23               24
# 28       18         4        21               28
# 29       24        21        27               30
#
# [30 rows x 54 columns]

# %%
# Merge the two dataframes
merged = pd.merge(
stats_df,
standings_df,
left_on='TEAM_ID',
right_on='TeamID',
how='inner'
)
merged

# Filter the merged dataframe to keep only the relevant columns
columns_to_keep = [
    'TEAM_ID', 'TEAM_NAME', 'Conference', 'PlayoffRank',
    'WinPCT', 'FG_PCT', 'FG3_PCT', 'FT_PCT',
    'REB', 'AST', 'TOV', 'STL', 'BLK', 'BLKA',
    'PTS', 'PLUS_MINUS'
]
merged_filtered = merged[[col for col in columns_to_keep if col in merged.columns]]
# merged_filtered.sort_values(by=['Conference', 'PlayoffRank'])
east = merged_filtered[merged_filtered['Conference'] == 'East'].sort_values(by='PlayoffRank').head(8)
west = merged_filtered[merged_filtered['Conference'] == 'West'].sort_values(by='PlayoffRank').head(8)
play_off_df = pd.concat([east, west]).sort_values(by=['Conference', 'PlayoffRank'])
# Out:
#        TEAM_ID               TEAM_NAME Conference  PlayoffRank  WinPCT  \
# 5   1610612739     Cleveland Cavaliers       East            1   0.780
# 1   1610612738          Boston Celtics       East            2   0.744
# 19  1610612752         New York Knicks       East            3   0.622
# 11  1610612754          Indiana Pacers       East            4   0.610
# 16  1610612749         Milwaukee Bucks       East            5   0.585
# 8   1610612765         Detroit Pistons       East            6   0.537
# 21  1610612753           Orlando Magic       East            7   0.500
# 0   1610612737           Atlanta Hawks       East            8   0.488
# 20  1610612760   Oklahoma City Thunder       West            1   0.829
# 10  1610612745         Houston Rockets       West            2   0.634
# 13  1610612747      Los Angeles Lakers       West            3   0.610
# 7   1610612743          Denver Nuggets       West            4   0.610
# 12  1610612746             LA Clippers       West            5   0.610
# 17  1610612750  Minnesota Timberwolves       West            6   0.598
# 9   1610612744   Golden State Warriors       West            7   0.585
# 14  1610612763       Memphis Grizzlies       West            8   0.585
#
#     FG_PCT  FG3_PCT  FT_PCT   REB   AST     TOV  STL  BLK  BLKA   PTS  \
# 5    0.491    0.383   0.776  3723  2304  1082.0  670  350   361  9999
# 1    0.462    0.368   0.799  3716  2144   973.0  589  452   295  9534
# 19   0.486    0.369   0.800  3497  2254  1088.0  671  324   406  9494
# 11   0.488    0.368   0.789  3430  2398  1082.0  694  448   366  9624
# 16   0.486    0.387   0.750  3556  2090  1097.0  601  384   315  9472
# 8    0.476    0.362   0.774  3670  2165  1218.0  652  431   413  9471
# 21   0.445    0.318   0.775  3431  1887  1165.0  729  488   361  8645
# 0    0.472    0.358   0.775  3649  2426  1273.0  798  419   403  9691
# 20   0.482    0.374   0.819  3672  2202   961.0  847  465   392  9881
# 10   0.455    0.353   0.738  3974  1914  1139.0  689  411   467  9372
# 13   0.479    0.366   0.785  3479  2131  1145.0  633  367   344  9298
# 7    0.506    0.376   0.770  3751  2542  1169.0  656  402   420  9902
# 12   0.482    0.373   0.797  3591  2064  1220.0  773  370   352  9256
# 17   0.468    0.377   0.789  3634  2142  1186.0  654  406   368  9372
# 9    0.451    0.364   0.764  3721  2386  1152.0  771  391   441  9331
# 14   0.479    0.367   0.786  3875  2330  1285.0  726  462   450  9980
#
#     PLUS_MINUS
# 5        782.0
# 1        747.0
# 19       336.0
# 11       183.0
# 16       203.0
# 8        156.0
# 21       -10.0
# 0        -93.0
# 20      1055.0
# 10       370.0
# 13       100.0
# 7        319.0
# 12       382.0
# 17       410.0
# 9        271.0
# 14       398.0

# %%
play_off_df.to_csv(f'playoff_teams_{year}.csv', index=False)
